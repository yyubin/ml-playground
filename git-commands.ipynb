# %%
pwd
# Out:
# '/content'

# %%
cd drive/MyDrive
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive'
# /content/drive/MyDrive/colab/ml-playground

# %%
cd colab
# Out:
# [Errno 2] No such file or directory: 'colab'
# /content/drive/MyDrive/colab/ml-playground

# %%
cd ml-playground
# Out:
# [Errno 2] No such file or directory: 'ml-playground'
# /content/drive/MyDrive/colab/ml-playground

# %%
# !git add .

# %%
# !git commit -m "add logistic loss function differential proof"
# Out:
# [main 735dd3b] add logistic loss function differential proof
#  2 files changed, 2 insertions(+), 2 deletions(-)

# %%
# !git config --global user.email "hazing120@gmail.com"

# %%
# !git config --global user.name "yyubin"

# %%
# !git push origin main
# Out:
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 2.48 KiB | 158.00 KiB/s, done.
# Total 5 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/yyubin/ml-playground.git
#    f409c71..735dd3b  main -> main
