# %%
pwd
# Out:
# '/content'

# %%
cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
cd colab
# Out:
# /content/drive/MyDrive/colab

# %%
cd ml-playground
# Out:
# /content/drive/MyDrive/colab/ml-playground

# %%
# !git add .

# %%
# !git commit -m "linear regression theory, diabetes practice"
# Out:
# [main 82d3ca1] linear regression theory, diabetes practice
#  5 files changed, 4 insertions(+), 1 deletion(-)
#  delete mode 100644 Untitled0.ipynb
#  create mode 100644 git-commands.ipynb
#  create mode 100644 practice/linear-regression-diabetes.ipynb
#  create mode 100644 practice/linear-regression.ipynb
#  create mode 100644 practice/numpy01.ipynb

# %%
# !git config --global user.email "hazing120@gmail.com"

# %%
# !git config --global user.name "yyubin"

# %%
# !git push origin main
# Out:
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 197.97 KiB | 4.40 MiB/s, done.
# Total 7 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/yyubin/ml-playground.git
#    79dfcf0..82d3ca1  main -> main
