# %%
pwd
# Out:
# '/content'

# %%
cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
cd colab
# Out:
# /content/drive/MyDrive/colab

# %%
cd ml-playground
# Out:
# /content/drive/MyDrive/colab/ml-playground

# %%
# !git add .

# %%
# !git commit -m "add wisconsin-breast-cancer with logistic"
# Out:
# [main b260a5e] add wisconsin-breast-cancer with logistic
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  rewrite git-commands.ipynb (82%)
#  create mode 100644 practice/wisconsin-breast-cancer.ipynb

# %%
# !git config --global user.email "hazing120@gmail.com"

# %%
# !git config --global user.name "yyubin"

# %%
# !git push origin main
# Out:
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 54.86 KiB | 2.61 MiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/yyubin/ml-playground.git
#    735dd3b..b260a5e  main -> main
