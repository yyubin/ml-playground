# %%
pwd
# Out:
# '/content'

# %%
cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
cd colab
# Out:
# /content/drive/MyDrive/colab

# %%
cd ml-playground
# Out:
# /content/drive/MyDrive/colab/ml-playground

# %%
# !git add .

# %%
# !git commit -m "add neuron class"
# Out:
# [main afd67b0] add neuron class
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite git-commands.ipynb (95%)
#  rewrite practice/linear-regression-diabetes.ipynb (96%)

# %%
# !git config --global user.email "hazing120@gmail.com"

# %%
# !git config --global user.name "yyubin"

# %%
# !git push origin main
# Out:
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 2.02 KiB | 90.00 KiB/s, done.
# Total 5 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/yyubin/ml-playground.git
#    82d3ca1..afd67b0  main -> main
